# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_diabates= pd.read_csv('diabetes.csv')

# %%
data_diabates.head(7)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1

# %% [markdown]
# show the first 7 column

# %% [markdown]
# # New Section

# %%
data_diabates.shape
# Out:
# (768, 9)

# %%
data_diabates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data_diabates.describe
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
data_diabates.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X = data_diabates.iloc[:, :-1]  # Input features (all columns except last)
y = data_diabates.iloc[:, -1]   # Output (target variable, last column)

# %%
# Creating Histogram
sns.histplot(x='BloodPressure', data = data_diabates, bins=[i for i in range(0,81,10)])


plt.plot(['Outcome' for i in range(0, 250)], [i for i in range(0, 250)], c='red')

plt.show()

# %%
# Plot histogram
plt.figure(figsize=(8, 5))
sns.histplot(data=data_diabates, x='BloodPressure', hue='Outcome', bins=20, kde=True, alpha=0.6)

# Labels and title
plt.xlabel('Blood Pressure')
plt.ylabel('Count')
plt.title('Histogram of Blood Pressure by Outcome')
plt.legend(title='Outcome', labels=['Non-Diabetic (0)', 'Diabetic (1)'])

# Show plot
plt.show()
