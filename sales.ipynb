# %%
import pandas as pd

# %%
df = pd.read_csv('sales_data.csv')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
df.head(10)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2  2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4  2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.0       500.0
# 6  2018-04-18  Central   Martha     Steven    Television   75.0      1198.0
# 7  2018-05-05  Central  Hermann       Luis    Television   90.0      1198.0
# 8  2018-05-22     West  Douglas    Michael    Television   32.0      1198.0
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0
# 5   30000.0
# 6   89850.0
# 7  107820.0
# 8   38336.0
# 9   30000.0

# %%
df.tail(3)
# Out:
#      OrderDate   Region Manager SalesMan          Item   Units  Unit_price  \
# 42  2019-12-21  Central  Martha   Steven  Home Theater   28.00     500.000
# 43         NaN      NaN     NaN      NaN           NaN  278.00    1125.000
# 44         NaN      NaN     NaN      NaN           NaN   34.75     140.625
#
#     Sale_amt
# 42  14000.00
# 43  62550.00
# 44   7818.75

# %%
df.dtypes
# Out:
# OrderDate      object
# Region         object
# Manager        object
# SalesMan       object
# Item           object
# Units         float64
# Unit_price    float64
# Sale_amt      float64
# dtype: object

# %%
df.nunique()
# Out:
# OrderDate     43
# Region         3
# Manager        4
# SalesMan      11
# Item           5
# Units         39
# Unit_price     7
# Sale_amt      42
# dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df['Region'].value_counts()
# Out:
# Region
# Central    24
# East       13
# West        6
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# OrderDate     2
# Region        2
# Manager       2
# SalesMan      2
# Item          2
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
df.describe()
# Out:
#             Units   Unit_price       Sale_amt
# count   45.000000    45.000000      45.000000
# mean    54.083333   583.313889   30578.761111
# std     45.096676   444.806622   32227.534943
# min      2.000000    58.500000     250.000000
# 25%     28.000000   225.000000    4329.000000
# 50%     53.000000   500.000000   17100.000000
# 75%     75.000000  1198.000000   43128.000000
# max    278.000000  1198.000000  113810.000000

# %%
df['SalesMan']
# Out:
# 0     Alexander
# 1        Shelli
# 2          Luis
# 3         David
# 4       Stephen
# 5     Alexander
# 6        Steven
# 7          Luis
# 8       Michael
# 9     Alexander
# 10        Sigal
# 11        Diana
# 12        Karen
# 13    Alexander
# 14         John
# 15    Alexander
# 16        Sigal
# 17    Alexander
# 18        Karen
# 19       Shelli
# 20         John
# 21        Karen
# 22        David
# 23         John
# 24    Alexander
# 25      Stephen
# 26         Luis
# 27       Steven
# 28        Diana
# 29        David
# 30        David
# 31       Shelli
# 32    Alexander
# 33        Sigal
# 34       Shelli
# 35      Stephen
# 36        David
# 37      Stephen
# 38      Michael
# 39       Steven
# 40         Luis
# 41         Luis
# 42       Steven
# 43          NaN
# 44          NaN
# Name: SalesMan, dtype: object

# %%
df[df['Units']>50]
# Out:
#      OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0   2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 4   2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
# 5   2018-04-01     East   Martha  Alexander  Home Theater   60.0       500.0
# 6   2018-04-18  Central   Martha     Steven    Television   75.0      1198.0
# 7   2018-05-05  Central  Hermann       Luis    Television   90.0      1198.0
# 9   2018-06-08     East   Martha  Alexander  Home Theater   60.0       500.0
# 10  2018-06-25  Central  Hermann      Sigal    Television   90.0      1198.0
# 12  2018-07-29     East  Douglas      Karen  Home Theater   81.0       500.0
# 17  2018-10-22     East   Martha  Alexander    Cell Phone   64.0       225.0
# 19  2018-11-25  Central  Hermann     Shelli   Video Games   96.0        58.5
# 20  2018-12-12  Central  Douglas       John    Television   67.0      1198.0
# 21  2018-12-29     East  Douglas      Karen   Video Games   74.0        58.5
# 23  2019-02-01  Central  Douglas       John  Home Theater   87.0       500.0
# 27  2019-04-10  Central   Martha     Steven    Television   66.0      1198.0
# 28  2019-04-27     East   Martha      Diana    Cell Phone   96.0       225.0
# 29  2019-05-14  Central  Timothy      David    Television   53.0      1198.0
# 30  2019-05-31  Central  Timothy      David  Home Theater   80.0       500.0
# 32  2019-07-04     East   Martha  Alexander   Video Games   62.0        58.5
# 33  2019-07-21  Central  Hermann      Sigal   Video Games   55.0        58.5
# 37  2019-09-27     West  Timothy    Stephen    Cell Phone   76.0       225.0
# 38  2019-10-14     West  Douglas    Michael  Home Theater   57.0       500.0
# 41  2019-12-04  Central  Hermann       Luis  Home Theater   94.0       500.0
# 43         NaN      NaN      NaN        NaN           NaN  278.0      1125.0
#
#     Sale_amt
# 0   113810.0
# 4    67088.0
# 5    30000.0
# 6    89850.0
# 7   107820.0
# 9    30000.0
# 10  107820.0
# 12   40500.0
# 17   14400.0
# 19    5616.0
# 20   80266.0
# 21    4329.0
# 23   43500.0
# 27   79068.0
# 28   21600.0
# 29   63494.0
# 30   40000.0
# 32    3627.0
# 33    3217.5
# 37   17100.0
# 38   28500.0
# 41   47000.0
# 43   62550.0

# %%
df.sort_values(by='Sale_amt',ascending=False)
# Out:
#      OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0   2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 7   2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 10  2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# 6   2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 20  2018-12-12  Central  Douglas       John    Television   67.00    1198.000
# 27  2019-04-10  Central   Martha     Steven    Television   66.00    1198.000
# 4   2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 29  2019-05-14  Central  Timothy      David    Television   53.00    1198.000
# 43         NaN      NaN      NaN        NaN           NaN  278.00    1125.000
# 41  2019-12-04  Central  Hermann       Luis  Home Theater   94.00     500.000
# 23  2019-02-01  Central  Douglas       John  Home Theater   87.00     500.000
# 2   2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 13  2018-08-15     East   Martha  Alexander    Television   35.00    1198.000
# 12  2018-07-29     East  Douglas      Karen  Home Theater   81.00     500.000
# 30  2019-05-31  Central  Timothy      David  Home Theater   80.00     500.000
# 8   2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9   2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 5   2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 38  2019-10-14     West  Douglas    Michael  Home Theater   57.00     500.000
# 1   2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 22  2019-01-15  Central  Timothy      David  Home Theater   46.00     500.000
# 28  2019-04-27     East   Martha      Diana    Cell Phone   96.00     225.000
# 37  2019-09-27     West  Timothy    Stephen    Cell Phone   76.00     225.000
# 39  2019-10-31  Central   Martha     Steven    Television   14.00    1198.000
# 11  2018-07-12     East   Martha      Diana  Home Theater   29.00     500.000
# 17  2018-10-22     East   Martha  Alexander    Cell Phone   64.00     225.000
# 42  2019-12-21  Central   Martha     Steven  Home Theater   28.00     500.000
# 16  2018-10-05  Central  Hermann      Sigal  Home Theater   28.00     500.000
# 36  2019-09-10  Central  Timothy      David    Television    7.00    1198.000
# 44         NaN      NaN      NaN        NaN           NaN   34.75     140.625
# 3   2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 19  2018-11-25  Central  Hermann     Shelli   Video Games   96.00      58.500
# 40  2019-11-17  Central  Hermann       Luis  Home Theater   11.00     500.000
# 21  2018-12-29     East  Douglas      Karen   Video Games   74.00      58.500
# 32  2019-07-04     East   Martha  Alexander   Video Games   62.00      58.500
# 25  2019-03-07     West  Timothy    Stephen  Home Theater    7.00     500.000
# 18  2018-11-08     East  Douglas      Karen    Cell Phone   15.00     225.000
# 33  2019-07-21  Central  Hermann      Sigal   Video Games   55.00      58.500
# 26  2019-03-24  Central  Hermann       Luis   Video Games   50.00      58.500
# 34  2019-08-07  Central  Hermann     Shelli   Video Games   42.00      58.500
# 24  2019-02-18     East   Martha  Alexander  Home Theater    4.00     500.000
# 15  2018-09-18     East   Martha  Alexander   Video Games   16.00      58.500
# 31  2019-06-17  Central  Hermann     Shelli          Desk    5.00     125.000
# 35  2019-08-24     West  Timothy    Stephen          Desk    3.00     125.000
# 14  2018-09-01  Central  Douglas       John          Desk    2.00     125.000
#
#      Sale_amt
# 0   113810.00
# 7   107820.00
# 10  107820.00
# 6    89850.00
# 20   80266.00
# 27   79068.00
# 4    67088.00
# 29   63494.00
# 43   62550.00
# 41   47000.00
# 23   43500.00
# 2    43128.00
# 13   41930.00
# 12   40500.00
# 30   40000.00
# 8    38336.00
# 9    30000.00
# 5    30000.00
# 38   28500.00
# 1    25000.00
# 22   23000.00
# 28   21600.00
# 37   17100.00
# 39   16772.00
# 11   14500.00
# 17   14400.00
# 42   14000.00
# 16   14000.00
# 36    8386.00
# 44    7818.75
# 3     6075.00
# 19    5616.00
# 40    5500.00
# 21    4329.00
# 32    3627.00
# 25    3500.00
# 18    3375.00
# 33    3217.50
# 26    2925.00
# 34    2457.00
# 24    2000.00
# 15     936.00
# 31     625.00
# 35     375.00
# 14     250.00

# %%
df.drop(columns=['Manager'], inplace=True)
df.head()
# Out:
#     OrderDate   Region   SalesMan          Item  Units  Unit_price  Sale_amt
# 0  2018-01-06     East  Alexander    Television   95.0      1198.0  113810.0
# 1  2018-01-23  Central     Shelli  Home Theater   50.0       500.0   25000.0
# 2  2018-02-09  Central       Luis    Television   36.0      1198.0   43128.0
# 3  2018-02-26  Central      David    Cell Phone   27.0       225.0    6075.0
# 4  2018-03-15     West    Stephen    Television   56.0      1198.0   67088.0

# %%
df.rename(columns={'Item':'Product'},inplace=True)
df.head()
# Out:
#     OrderDate   Region   SalesMan       Product  Units  Unit_price  Sale_amt
# 0  2018-01-06     East  Alexander    Television   95.0      1198.0  113810.0
# 1  2018-01-23  Central     Shelli  Home Theater   50.0       500.0   25000.0
# 2  2018-02-09  Central       Luis    Television   36.0      1198.0   43128.0
# 3  2018-02-26  Central      David    Cell Phone   27.0       225.0    6075.0
# 4  2018-03-15     West    Stephen    Television   56.0      1198.0   67088.0

# %%
df['Units']=df['Units'].astype(int)

# %%
df.groupby('Region').agg({'Sale_amt':'sum'})
# Out:
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %%
df.pivot_table(values='Sale_amt',index='Region',columns='Product' ,aggfunc='sum')
# Out:
# Product  Cell Phone   Desk  Home Theater  Television  Video Games
# Region
# Central      6075.0  875.0      212000.0    596604.0      14215.5
# East        39375.0    NaN      117000.0    155740.0       8892.0
# West        17100.0  375.0       32000.0    105424.0          NaN

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2f6f6606aa2c> in <cell line: 0>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1692                 arr.flags.writeable = False
#    1693         else:
# -> 1694             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695             # The underlying data was copied within _interleave, so no need
#    1696             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1751             else:
#    1752                 arr = blk.get_values(dtype)
# -> 1753             result[rl.indexer] = arr
#    1754             itemmask[rl.indexer] = 1
#    1755
#
# ValueError: could not convert string to float: '2018-01-06'

# %%
df['Year']=pd.DatetimeIndex(df['OrderDate']).year
df.head()
df['Month']=pd.DatetimeIndex(df['OrderDate']).month
df.head()
# Out:
#     OrderDate   Region   SalesMan       Product  Units  Unit_price  Sale_amt  \
# 0  2018-01-06     East  Alexander    Television     95      1198.0  113810.0
# 1  2018-01-23  Central     Shelli  Home Theater     50       500.0   25000.0
# 2  2018-02-09  Central       Luis    Television     36      1198.0   43128.0
# 3  2018-02-26  Central      David    Cell Phone     27       225.0    6075.0
# 4  2018-03-15     West    Stephen    Television     56      1198.0   67088.0
#
#      Year  Month
# 0  2018.0    1.0
# 1  2018.0    1.0
# 2  2018.0    2.0
# 3  2018.0    2.0
# 4  2018.0    3.0

# %%
df['Sale_amt'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.sort_values(by='Sale_amt',ascending=False)
# Out:
#      OrderDate   Region   SalesMan       Product  Units  Unit_price  \
# 0   2018-01-06     East  Alexander    Television     95    1198.000
# 7   2018-05-05  Central       Luis    Television     90    1198.000
# 10  2018-06-25  Central      Sigal    Television     90    1198.000
# 6   2018-04-18  Central     Steven    Television     75    1198.000
# 20  2018-12-12  Central       John    Television     67    1198.000
# 27  2019-04-10  Central     Steven    Television     66    1198.000
# 4   2018-03-15     West    Stephen    Television     56    1198.000
# 29  2019-05-14  Central      David    Television     53    1198.000
# 43         NaN      NaN        NaN           NaN    278    1125.000
# 41  2019-12-04  Central       Luis  Home Theater     94     500.000
# 23  2019-02-01  Central       John  Home Theater     87     500.000
# 2   2018-02-09  Central       Luis    Television     36    1198.000
# 13  2018-08-15     East  Alexander    Television     35    1198.000
# 12  2018-07-29     East      Karen  Home Theater     81     500.000
# 30  2019-05-31  Central      David  Home Theater     80     500.000
# 8   2018-05-22     West    Michael    Television     32    1198.000
# 9   2018-06-08     East  Alexander  Home Theater     60     500.000
# 5   2018-04-01     East  Alexander  Home Theater     60     500.000
# 38  2019-10-14     West    Michael  Home Theater     57     500.000
# 1   2018-01-23  Central     Shelli  Home Theater     50     500.000
# 22  2019-01-15  Central      David  Home Theater     46     500.000
# 28  2019-04-27     East      Diana    Cell Phone     96     225.000
# 37  2019-09-27     West    Stephen    Cell Phone     76     225.000
# 39  2019-10-31  Central     Steven    Television     14    1198.000
# 11  2018-07-12     East      Diana  Home Theater     29     500.000
# 17  2018-10-22     East  Alexander    Cell Phone     64     225.000
# 42  2019-12-21  Central     Steven  Home Theater     28     500.000
# 16  2018-10-05  Central      Sigal  Home Theater     28     500.000
# 36  2019-09-10  Central      David    Television      7    1198.000
# 44         NaN      NaN        NaN           NaN     34     140.625
# 3   2018-02-26  Central      David    Cell Phone     27     225.000
# 19  2018-11-25  Central     Shelli   Video Games     96      58.500
# 40  2019-11-17  Central       Luis  Home Theater     11     500.000
# 21  2018-12-29     East      Karen   Video Games     74      58.500
# 32  2019-07-04     East  Alexander   Video Games     62      58.500
# 25  2019-03-07     West    Stephen  Home Theater      7     500.000
# 18  2018-11-08     East      Karen    Cell Phone     15     225.000
# 33  2019-07-21  Central      Sigal   Video Games     55      58.500
# 26  2019-03-24  Central       Luis   Video Games     50      58.500
# 34  2019-08-07  Central     Shelli   Video Games     42      58.500
# 24  2019-02-18     East  Alexander  Home Theater      4     500.000
# 15  2018-09-18     East  Alexander   Video Games     16      58.500
# 31  2019-06-17  Central     Shelli          Desk      5     125.000
# 35  2019-08-24     West    Stephen          Desk      3     125.000
# 14  2018-09-01  Central       John          Desk      2     125.000
#
#      Sale_amt    Year  Month
# 0   113810.00  2018.0    1.0
# 7   107820.00  2018.0    5.0
# 10  107820.00  2018.0    6.0
# 6    89850.00  2018.0    4.0
# 20   80266.00  2018.0   12.0
# 27   79068.00  2019.0    4.0
# 4    67088.00  2018.0    3.0
# 29   63494.00  2019.0    5.0
# 43   62550.00     NaN    NaN
# 41   47000.00  2019.0   12.0
# 23   43500.00  2019.0    2.0
# 2    43128.00  2018.0    2.0
# 13   41930.00  2018.0    8.0
# 12   40500.00  2018.0    7.0
# 30   40000.00  2019.0    5.0
# 8    38336.00  2018.0    5.0
# 9    30000.00  2018.0    6.0
# 5    30000.00  2018.0    4.0
# 38   28500.00  2019.0   10.0
# 1    25000.00  2018.0    1.0
# 22   23000.00  2019.0    1.0
# 28   21600.00  2019.0    4.0
# 37   17100.00  2019.0    9.0
# 39   16772.00  2019.0   10.0
# 11   14500.00  2018.0    7.0
# 17   14400.00  2018.0   10.0
# 42   14000.00  2019.0   12.0
# 16   14000.00  2018.0   10.0
# 36    8386.00  2019.0    9.0
# 44    7818.75     NaN    NaN
# 3     6075.00  2018.0    2.0
# 19    5616.00  2018.0   11.0
# 40    5500.00  2019.0   11.0
# 21    4329.00  2018.0   12.0
# 32    3627.00  2019.0    7.0
# 25    3500.00  2019.0    3.0
# 18    3375.00  2018.0   11.0
# 33    3217.50  2019.0    7.0
# 26    2925.00  2019.0    3.0
# 34    2457.00  2019.0    8.0
# 24    2000.00  2019.0    2.0
# 15     936.00  2018.0    9.0
# 31     625.00  2019.0    6.0
# 35     375.00  2019.0    8.0
# 14     250.00  2018.0    9.0

# %%
df.shape
# Out:
# (45, 9)

# %%
df.to_dict()
# Out:
# {'OrderDate': {0: '2018-01-06',
#   1: '2018-01-23',
#   2: '2018-02-09',
#   3: '2018-02-26',
#   4: '2018-03-15',
#   5: '2018-04-01',
#   6: '2018-04-18',
#   7: '2018-05-05',
#   8: '2018-05-22',
#   9: '2018-06-08',
#   10: '2018-06-25',
#   11: '2018-07-12',
#   12: '2018-07-29',
#   13: '2018-08-15',
#   14: '2018-09-01',
#   15: '2018-09-18',
#   16: '2018-10-05',
#   17: '2018-10-22',
#   18: '2018-11-08',
#   19: '2018-11-25',
#   20: '2018-12-12',
#   21: '2018-12-29',
#   22: '2019-01-15',
#   23: '2019-02-01',
#   24: '2019-02-18',
#   25: '2019-03-07',
#   26: '2019-03-24',
#   27: '2019-04-10',
#   28: '2019-04-27',
#   29: '2019-05-14',
#   30: '2019-05-31',
#   31: '2019-06-17',
#   32: '2019-07-04',
#   33: '2019-07-21',
#   34: '2019-08-07',
#   35: '2019-08-24',
#   36: '2019-09-10',
#   37: '2019-09-27',
#   38: '2019-10-14',
#   39: '2019-10-31',
#   40: '2019-11-17',
#   41: '2019-12-04',
#   42: '2019-12-21',
#   43: nan,
#   44: nan},
#  'Region': {0: 'East',
#   1: 'Central',
#   2: 'Central',
#   3: 'Central',
#   4: 'West',
#   5: 'East',
#   6: 'Central',
#   7: 'Central',
#   8: 'West',
#   9: 'East',
#   10: 'Central',
#   11: 'East',
#   12: 'East',
#   13: 'East',
#   14: 'Central',
#   15: 'East',
#   16: 'Central',
#   17: 'East',
#   18: 'East',
#   19: 'Central',
#   20: 'Central',
#   21: 'East',
#   22: 'Central',
#   23: 'Central',
#   24: 'East',
#   25: 'West',
#   26: 'Central',
#   27: 'Central',
#   28: 'East',
#   29: 'Central',
#   30: 'Central',
#   31: 'Central',
#   32: 'East',
#   33: 'Central',
#   34: 'Central',
#   35: 'West',
#   36: 'Central',
#   37: 'West',
#   38: 'West',
#   39: 'Central',
#   40: 'Central',
#   41: 'Central',
#   42: 'Central',
#   43: nan,
#   44: nan},
#  'SalesMan': {0: 'Alexander',
#   1: 'Shelli',
#   2: 'Luis',
#   3: 'David',
#   4: 'Stephen',
#   5: 'Alexander',
#   6: 'Steven',
#   7: 'Luis',
#   8: 'Michael',
#   9: 'Alexander',
#   10: 'Sigal',
#   11: 'Diana',
#   12: 'Karen',
#   13: 'Alexander',
#   14: 'John',
#   15: 'Alexander',
#   16: 'Sigal',
#   17: 'Alexander',
#   18: 'Karen',
#   19: 'Shelli',
#   20: 'John',
#   21: 'Karen',
#   22: 'David',
#   23: 'John',
#   24: 'Alexander',
#   25: 'Stephen',
#   26: 'Luis',
#   27: 'Steven',
#   28: 'Diana',
#   29: 'David',
#   30: 'David',
#   31: 'Shelli',
#   32: 'Alexander',
#   33: 'Sigal',
#   34: 'Shelli',
#   35: 'Stephen',
#   36: 'David',
#   37: 'Stephen',
#   38: 'Michael',
#   39: 'Steven',
#   40: 'Luis',
#   41: 'Luis',
#   42: 'Steven',
#   43: nan,
#   44: nan},
#  'Product': {0: 'Television',
#   1: 'Home Theater',
#   2: 'Television',
#   3: 'Cell Phone',
#   4: 'Television',
#   5: 'Home Theater',
#   6: 'Television',
#   7: 'Television',
#   8: 'Television',
#   9: 'Home Theater',
#   10: 'Television',
#   11: 'Home Theater',
#   12: 'Home Theater',
#   13: 'Television',
#   14: 'Desk',
#   15: 'Video Games',
#   16: 'Home Theater',
#   17: 'Cell Phone',
#   18: 'Cell Phone',
#   19: 'Video Games',
#   20: 'Television',
#   21: 'Video Games',
#   22: 'Home Theater',
#   23: 'Home Theater',
#   24: 'Home Theater',
#   25: 'Home Theater',
#   26: 'Video Games',
#   27: 'Television',
#   28: 'Cell Phone',
#   29: 'Television',
#   30: 'Home Theater',
#   31: 'Desk',
#   32: 'Video Games',
#   33: 'Video Games',
#   34: 'Video Games',
#   35: 'Desk',
#   36: 'Television',
#   37: 'Cell Phone',
#   38: 'Home Theater',
#   39: 'Television',
#   40: 'Home Theater',
#   41: 'Home Theater',
#   42: 'Home Theater',
#   43: nan,
#   44: nan},
#  'Units': {0: 95,
#   1: 50,
#   2: 36,
#   3: 27,
#   4: 56,
#   5: 60,
#   6: 75,
#   7: 90,
#   8: 32,
#   9: 60,
#   10: 90,
#   11: 29,
#   12: 81,
#   13: 35,
#   14: 2,
#   15: 16,
#   16: 28,
#   17: 64,
#   18: 15,
#   19: 96,
#   20: 67,
#   21: 74,
#   22: 46,
#   23: 87,
#   24: 4,
#   25: 7,
#   26: 50,
#   27: 66,
#   28: 96,
#   29: 53,
#   30: 80,
#   31: 5,
#   32: 62,
#   33: 55,
#   34: 42,
#   35: 3,
#   36: 7,
#   37: 76,
#   38: 57,
#   39: 14,
#   40: 11,
#   41: 94,
#   42: 28,
#   43: 278,
#   44: 34},
#  'Unit_price': {0: 1198.0,
#   1: 500.0,
#   2: 1198.0,
#   3: 225.0,
#   4: 1198.0,
#   5: 500.0,
#   6: 1198.0,
#   7: 1198.0,
#   8: 1198.0,
#   9: 500.0,
#   10: 1198.0,
#   11: 500.0,
#   12: 500.0,
#   13: 1198.0,
#   14: 125.0,
#   15: 58.5,
#   16: 500.0,
#   17: 225.0,
#   18: 225.0,
#   19: 58.5,
#   20: 1198.0,
#   21: 58.5,
#   22: 500.0,
#   23: 500.0,
#   24: 500.0,
#   25: 500.0,
#   26: 58.5,
#   27: 1198.0,
#   28: 225.0,
#   29: 1198.0,
#   30: 500.0,
#   31: 125.0,
#   32: 58.5,
#   33: 58.5,
#   34: 58.5,
#   35: 125.0,
#   36: 1198.0,
#   37: 225.0,
#   38: 500.0,
#   39: 1198.0,
#   40: 500.0,
#   41: 500.0,
#   42: 500.0,
#   43: 1125.0,
#   44: 140.625},
#  'Sale_amt': {0: 113810.0,
#   1: 25000.0,
#   2: 43128.0,
#   3: 6075.0,
#   4: 67088.0,
#   5: 30000.0,
#   6: 89850.0,
#   7: 107820.0,
#   8: 38336.0,
#   9: 30000.0,
#   10: 107820.0,
#   11: 14500.0,
#   12: 40500.0,
#   13: 41930.0,
#   14: 250.0,
#   15: 936.0,
#   16: 14000.0,
#   17: 14400.0,
#   18: 3375.0,
#   19: 5616.0,
#   20: 80266.0,
#   21: 4329.0,
#   22: 23000.0,
#   23: 43500.0,
#   24: 2000.0,
#   25: 3500.0,
#   26: 2925.0,
#   27: 79068.0,
#   28: 21600.0,
#   29: 63494.0,
#   30: 40000.0,
#   31: 625.0,
#   32: 3627.0,
#   33: 3217.5,
#   34: 2457.0,
#   35: 375.0,
#   36: 8386.0,
#   37: 17100.0,
#   38: 28500.0,
#   39: 16772.0,
#   40: 5500.0,
#   41: 47000.0,
#   42: 14000.0,
#   43: 62550.0,
#   44: 7818.75},
#  'Year': {0: 2018.0,
#   1: 2018.0,
#   2: 2018.0,
#   3: 2018.0,
#   4: 2018.0,
#   5: 2018.0,
#   6: 2018.0,
#   7: 2018.0,
#   8: 2018.0,
#   9: 2018.0,
#   10: 2018.0,
#   11: 2018.0,
#   12: 2018.0,
#   13: 2018.0,
#   14: 2018.0,
#   15: 2018.0,
#   16: 2018.0,
#   17: 2018.0,
#   18: 2018.0,
#   19: 2018.0,
#   20: 2018.0,
#   21: 2018.0,
#   22: 2019.0,
#   23: 2019.0,
#   24: 2019.0,
#   25: 2019.0,
#   26: 2019.0,
#   27: 2019.0,
#   28: 2019.0,
#   29: 2019.0,
#   30: 2019.0,
#   31: 2019.0,
#   32: 2019.0,
#   33: 2019.0,
#   34: 2019.0,
#   35: 2019.0,
#   36: 2019.0,
#   37: 2019.0,
#   38: 2019.0,
#   39: 2019.0,
#   40: 2019.0,
#   41: 2019.0,
#   42: 2019.0,
#   43: nan,
#   44: nan},
#  'Month': {0: 1.0,
#   1: 1.0,
#   2: 2.0,
#   3: 2.0,
#   4: 3.0,
#   5: 4.0,
#   6: 4.0,
#   7: 5.0,
#   8: 5.0,
#   9: 6.0,
#   10: 6.0,
#   11: 7.0,
#   12: 7.0,
#   13: 8.0,
#   14: 9.0,
#   15: 9.0,
#   16: 10.0,
#   17: 10.0,
#   18: 11.0,
#   19: 11.0,
#   20: 12.0,
#   21: 12.0,
#   22: 1.0,
#   23: 2.0,
#   24: 2.0,
#   25: 3.0,
#   26: 3.0,
#   27: 4.0,
#   28: 4.0,
#   29: 5.0,
#   30: 5.0,
#   31: 6.0,
#   32: 7.0,
#   33: 7.0,
#   34: 8.0,
#   35: 8.0,
#   36: 9.0,
#   37: 9.0,
#   38: 10.0,
#   39: 10.0,
#   40: 11.0,
#   41: 12.0,
#   42: 12.0,
#   43: nan,
#   44: nan}}

# %%
df.set_index('OrderDate',inplace=True)

# %%
df.memory_usage(deep=True)
# Out:
# Index         4017
# Region        2759
# SalesMan      2774
# Product       2964
# Units          360
# Unit_price     360
# Sale_amt       360
# Year           360
# Month          360
# dtype: int64

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  Cell Phone  Desk  Home Theater  Television  Video Games
# Region
# Central           1     2             8           9            4
# East              3     0             5           2            3
# West              1     1             2           2            0
